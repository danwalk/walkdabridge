# %% [markdown]
# # Tips **

# %% [markdown]
# ### Step 1. Import the necessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# print the graphs in the notebook
# %matplotlib inline

# set seaborn style to white
sns.set_style("white")


# https://seaborn.pydata.org/tutorial/distributions.html

# https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('tips.csv', index_col=0)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
t = tips[['total_bill']]
tbill = t.hist(bins=15)


#https://seaborn.pydata.org/tutorial/distributions.html

# %%
sns.displot(t, x="total_bill", kde=True)

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
ti = tips[['tip']]
ttips = ti.hist()

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.distplot)
# Out:
# C:\Users\Daniel\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Daniel\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
ax1 = tips.plot.scatter(x='total_bill',
                      y='tip',
                      c='DarkBlue')

# %% [markdown]
# ### Step 7.  Create one image with the relationship of `total_bill`, `tip` and `size`.
# #### Hint: It is just one function.

# %%
fh = tips[['total_bill', 'tip', 'size']]
sns.pairplot(data = fh)

#https://www.geeksforgeeks.org/grid-plot-in-python-using-seaborn/

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
hh = tips[['day', 'total_bill', 'sex']]
sns.relplot(data = hh, x='day', y='total_bill')

# %%
sns.set_theme(style="whitegrid")
sns.stripplot(data = hh, x='day', y='total_bill', linewidth=1)

# https://seaborn.pydata.org/generated/seaborn.stripplot.html
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.stripplot(data = hh, y='day', x='total_bill', hue='sex', palette="Set1")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="time",
                 data=tips, linewidth=1, palette="Set2")

# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
sns.set_style("ticks")
sns.displot(tips, x="tip", col="time", aspect=1, color="darkblue")
#(function) sns.displot: (
    #data=None, # x=None, #   y=None, # hue=None,  #  row=None,  #  col=None, #   weights=None, #   kind='hist', #   rug=False,  #  rug_kws=None,  #  log_scale=None,  #  legend=True,   # palette=None, #   hue_order=None,    #hue_norm=None, #   color=None,  #  col_wrap=None,  #  row_order=None,  #  col_order=None,  #  height=5,  #  aspect=1,  #  facet_kws=None, #   **kwargs,


# https://www.codecademy.com/articles/seaborn-design-i#:~:text=Seaborn%20has%20five%20built%2Din,set_style()%20.

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
sns.relplot(data=tips, x="total_bill", y="tip", col="sex", hue="smoker", kind="scatter", palette="Set1")
