# %% [markdown]
# # Regular Expressions (RegEx)

# %% [markdown]
# A regular expression, regex or regexp is a sequence of characters that define a search pattern.

# %% [markdown]
# ![regex](https://miro.medium.com/max/1200/1*ZVlIZ1ZYC6rASz-dYPzhZQ.jpeg)

# %% [markdown]
# **references**
#
# - https://docs.python.org/3/howto/regex.html
# - https://www.datacamp.com/community/tutorials/python-regular-expression-tutorial
# - https://www.dataquest.io/blog/regular-expressions-data-scientists/
# - https://www.kaggle.com/rtatman/fraudulent-email-corpus
#
# **may save your life**
#
# - https://regex101.com/

# %% [markdown]
# ### First things first

# %% [markdown]
# For the standard case **import re** should be enough. For the later case **pip3 install regex** should install it.

# %%
import re
import numpy as np
import pandas as pd

# %% [markdown]
# ## Sintax
# ### Special Characters:
# - `.` Matches any character except a newline.
# - `^` Matches the start of the string.
# - `$` Matches the end of the string or just before the newline at the end of the string.
# - `*` Matches 0 or more repetitions of the preceding RE.
# - `+` Matches 1 or more repetitions of the preceding RE.
# - `?` Matches 0 or 1 repetitions of the preceding RE.
# - NOTA: re.M -> modo multilinea
#
# https://docs.python.org/3/library/re.html#re-syntax

# %% [markdown]
# ### Special Sequences:
#
# - **Literals** `a`
# - **Alternation** `a|b`
# - **Character sets** `[ab]`, `[^ab]`
# - **Wildcards** `.`
# - **Escape special characters** `\` (?,*,+,^,&)
# - **Ranges** `[a-d]`, `[1-9]`
#
# - **Quantifiers** `{2}`, `{2,}`, `{2,4}`, `?`, `*`, `+`
# - **Grouping** `()`
# - **Anchors** `^`, `$`
# - **Character classes** `\w`, `\d`, `\s`, `\n`, `\W`, `\D`, `\S`
#
# **\w** - Matches any alphanumeric character (digits and alphabets). Equivalent to `[a-zA-Z0-9_]`. By the way, underscore _ is also considered an alphanumeric character.
#
# **\d** - Matches any digit. Equivalent to `[0-9]`
#
# **\s** - Matches where a string contains any whitespace character. Equivalent to `[ \t\n\r\f\v]`
#
# **\W** - Matches any non-alphanumeric character. Equivalent to `[^a-zA-Z0-9_]`
#
# **\D** - Matches any non digit. Equivalent to `[^0-9]`
#
# **\S** - Matches where a string contains any non-whitespace character. Equivalent to `[^ \t\n\r\f\v]`

# %% [markdown]
# ### Methods

# %% [markdown]
# ### re.sub(pattern, repl, string, count=0)
# Replaces one or many matches with a string

# %%
txt = "gabriel, Mónica, Borja and Clara are TA's??"

# %%
#re.sub
#Literals
re.sub('g','G',txt)
# Out:
# "Gabriel, Mónica, Borja and Clara are TA's??"

# %%
#Ranges
re.sub('[A-Z]','',txt)
# Out:
# "gabriel, ónica, orja and lara are 's??"

# %%
#Escape special character, quantifiers
re.sub('\?{2}','.',txt)
# Out:
# "gabriel, Mónica, Borja and Clara are TA's."

# %% [markdown]
# ### re.search(pattern, string, flags=0)
# Scan through a string, looking for any location where this RE matches. If the search is succesful, `re.search()` returns a match object. Otherwise, it returns `None`.

# %%
#re.search
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt) 
x
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>

# %%
y = re.search("^Hola.*", txt) 
print(y)
# Out:
# None

# %%
txt = "The rain in Spain"
#\b whole words only
x = re.search(r"\bS\w+", txt)
print(x)
print(x.span())
#returns a tuple containing the start-, and end positions of the match
print(x.start())
#contains the start position of the match
print(x.end())
#contains the end position of the match
print(x.string)
#print the string passed into the function (variable 'txt')
print(x.group())
#Print the part of the string where there was a match
# Out:
# <re.Match object; span=(12, 17), match='Spain'>
# (12, 17)
# 12
# 17
# The rain in Spain
# Spain

# %%
print(re.search(r'r\w*', txt))
print(re.search(r'R\w*', txt))
print(re.search(r'^T\w*', txt))
print(re.search(r'^t\w*', txt))
# Out:
# <re.Match object; span=(4, 8), match='rain'>
# None
# <re.Match object; span=(0, 3), match='The'>
# None

# %% [markdown]
# ### re.match(pattern, string)
# Determine if the RE matches at the **beginning** of the string.

# %%
#re.match
pattern = r"Cookie"
sequence = "I want a Cookie"
sequence2= "Cookie, I want you!"
if re.match(pattern, sequence2):
    print("Match!")
else: 
    print("Not a match!")
# Out:
# Match!

# %%
txt = "The rain in Madrid"
#matches at the beginning of the string
print(re.match(r'r\w*', txt))
print(re.match(r'^r\w*', txt))
print(re.match(r'^T\w*', txt))
print(re.match(r'T\w*', txt))
# Out:
# None
# None
# <re.Match object; span=(0, 3), match='The'>
# <re.Match object; span=(0, 3), match='The'>

# %%
email_address = 'Please contact us at: support@thebridge.com'
match = re.search(r'(\w+)@([\w\.]+)', email_address)
if match:
    print(match.group()) # The whole matched text
    print(match.group(1)) # The username (group 1)
    print(match.group(2)) # The host (group 2)
# Out:
# support@thebridge.com
# support
# thebridge.com

# %% [markdown]
# ### re.fullmatch(pattern, string)

# %%
class_names = ["Karina", "Marina", "Isabel", "Gina", "Xinru", "Sonia", "Marycruz"]
for name in class_names:
    if re.fullmatch("Isabel", name):
        print(f"{name} is desired name")
    else:
        print(f"{name} is not desired name")
# Out:
# Karina is not desired name
# Marina is not desired name
# Isabel is desired name
# Gina is not desired name
# Xinru is not desired name
# Sonia is not desired name
# Marycruz is not desired name

# %% [markdown]
# ### re.findall (pattern, string)
# Find all substrings where the RE matches, and returns them as a list.

# %%
#re.findall
email_address = "Please contact us at: support.data@data-science.com, xyz@thebridge.com"

#'addresses' is a list that stores all the possible match
addresses = re.findall(r'[\w\.]+@[\w\.-]+', email_address)
addresses
# Out:
# ['support.data@data-science.com', 'xyz@thebridge.com']

# %%
print(re.findall('[^aeiou\s]',email_address))
# Out:
# ['P', 'l', 's', 'c', 'n', 't', 'c', 't', 's', 't', ':', 's', 'p', 'p', 'r', 't', '.', 'd', 't', '@', 'd', 't', '-', 's', 'c', 'n', 'c', '.', 'c', 'm', ',', 'x', 'y', 'z', '@', 't', 'h', 'b', 'r', 'd', 'g', '.', 'c', 'm']

# %% [markdown]
# **¿Qué me van a devolver las siguientes dos líneas de código?**

# %%
#print(re.findall('\sc\w*', email_address))
#print(re.findall('^P\w*', email_address))

# %% [markdown]
# ------------------------------------------------------------------------------

# %%
with open('info.txt', 'r') as file:
    client_info = file.read()

# %%
emails_clients=re.findall(r"[\w.]+@+[\w.]+", client_info)
print(emails_clients[:5])
# Out:
# ['sit.amet.metus@egestasnunc.ca', 'arcu.Aliquam.ultrices@vestibulumneceuismod.co.uk', 'Nulla.eu.neque@Fuscealiquetmagna.com', 'Nullam.velit@non.ca', 'In@gravidamolestiearcu.co.uk']

# %%
client_numbers = re.findall(r"[0-9]{2}-\d{3}-\d{3}-\d{3}", client_info)

# %%
print(client_numbers)
# Out:
# ['34-739-941-941', '34-278-870-242', '34-999-876-292', '34-345-887-949', '34-905-089-682', '34-773-463-479', '34-017-915-525', '34-274-204-840', '34-575-459-881', '34-249-358-256', '34-299-478-659', '34-094-099-748', '34-236-498-114', '34-541-455-803', '34-274-768-546', '34-850-484-655', '34-193-830-599', '34-768-704-320', '34-960-058-312', '34-835-461-291', '34-524-499-405', '34-553-655-405', '34-193-752-726', '34-165-726-657', '34-172-146-895', '34-309-707-078', '34-289-368-945', '34-432-424-781', '34-880-153-396', '34-876-903-767', '34-508-574-378', '34-219-498-365', '34-413-279-781', '34-789-736-506', '34-701-997-370', '34-912-146-256', '34-550-871-297', '34-818-230-259', '34-707-183-700', '34-006-975-807', '34-975-336-347', '34-208-023-425', '34-810-185-675', '34-318-817-026', '34-229-857-982', '34-415-168-417', '34-595-803-021', '34-620-827-404', '34-711-768-527', '34-159-329-878', '34-619-616-824', '34-865-861-872', '34-294-644-638', '34-439-853-222', '34-215-852-041', '34-425-519-500', '34-152-386-570', '34-114-918-271', '34-578-430-713', '34-198-215-014', '34-081-000-664', '34-215-712-522', '34-247-057-497', '34-091-856-589', '34-972-416-447', '34-371-921-059', '34-103-486-092', '34-093-803-387', '34-887-264-237', '34-396-708-852', '34-935-106-187', '34-719-648-197', '34-287-491-518', '34-190-000-222', '34-632-106-215', '34-236-373-612', '34-103-834-289', '34-247-496-116', '34-685-891-953', '34-382-619-851', '34-988-032-549', '34-827-702-441', '34-962-483-735', '34-045-897-696', '34-536-831-838', '34-008-550-220', '34-502-109-187', '34-259-454-764', '34-648-926-885', '34-131-055-768', '34-824-680-101', '34-390-299-105', '34-022-795-481', '34-033-595-405', '34-058-465-887', '34-857-529-653', '34-621-918-403', '34-715-306-812', '34-680-520-067', '34-870-684-275']

# %% [markdown]
# ### re.split(pattern, string, maxsplit=0)
# Returns a list where the string has been split at each match

# %%
#re.split
sente = "Hello,\n Please, contact me the sooner.\n Thank you,\n Me"

# %%
reg = re.split("\n ", sente)
reg
# Out:
# ['Hello,', 'Please, contact me the sooner.', 'Thank you,', 'Me']

# %%
"".join(reg)
# Out:
# 'Hello,Please, contact me the sooner.Thank you,Me'

# %% [markdown]
# ### re.compile(pattern
# Compiles a RE into a regular expression object.

# %%
name_check = re.compile(r"[^A-Za-z ]")

# %%
name = input("Please insert your name:")
while name_check.search(name):
    # it loops while if finds a match
    print("Please enter your name correctly!")
    name = input("Please insert your name:")
print("Finally mate, I thought you'd never do it")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-66bac771791f> in <module>
# ----> 1 name = input("Please insert your name:")
#       2 while name_check.search(name):
#       3     # it loops while if finds a match
#       4     print("Please enter your name correctly!")
#       5     name = input("Please insert your name:")
#
# ~\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Some practice
# Now is your turn.

# %% [markdown]
# #### Simple validation of a username
# https://www.codewars.com/kata/56a3f08aa9a6cc9b75000023
#
# Write a simple regex to validate a username. Allowed characters are:
#
# - lowercase letters,
# - numbers,
# - underscore
#
# Length should be between 4 and 16 characters (both included).

# %%
# your solution

# %%
def validate_usr(username):
    #your code here
    pass

# %% [markdown]
# #### Regex validate PIN code
#
# https://www.codewars.com/kata/55f8a9c06c018a0d6e000132
#
# ATM machines allow 4 or 6 digit PIN codes and PIN codes cannot contain anything but exactly 4 digits or exactly 6 digits.
#
# If the function is passed a valid PIN string, return true, else return false.
#
# Examples:
# ```python
# "1234"   -->  True
# "12345"  -->  False
# "a234"   -->  False
# ```

# %%
# your solution

# %%
def validate_pin(pin):
    #return true or false
    pass

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # The FBI challenge

# %% [markdown]
# - https://www.fbi.gov/scams-and-safety/common-fraud-schemes/nigerian-letter-or-419-fraud
# - https://www.kaggle.com/rtatman/fraudulent-email-corpus

# %% [markdown]
# It's your first day at the FBI office and your boss has just send you an `txt` file: `emails.txt`, she asked you to make some analysis but first of all, you need to get a dataframe like the following. You'll need some python knowledge and some regex for that goal.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Since we are good people, here you have a proposed solution

# %%
emails_info={}

# %%
fh = open("emails.txt", "r").read()

# %%
fh.count("From r")
# Out:
# 3977

# %%
contents = re.split(r"From r", fh)

# %%
contents[0]
# Out:
# ''

# %%
contents.pop(0)
# Out:
# ''

# %% [markdown]
# - sender_email
# - sender_name
# - date_sent
# - time_sent
# - subject

# %% [markdown]
# ### Info Sender

# %%
info_sender=[]
for i,e in enumerate(contents):
    try:
        info_sender.append(re.search("From:.*", e).group())
    except: 
        info_sender.append("not found")

# %%
len(info_sender)
# Out:
# 3977

# %%
#sender_email
emails_info['sender_email']=[]
for line in info_sender:
    res=re.findall(r'[\w\.]+@[\w\.-]+', line)
    if res:
        emails_info['sender_email'].append(res[0])
    else:
        emails_info['sender_email'].append(np.nan)
        
len(emails_info['sender_email'])
# Out:
# 3977

# %%
#sender name
emails_info['sender_name']=[]
for line in info_sender:
    res=re.findall(r':.*<', line)
    if res:
        emails_info['sender_name'].append(res[0][1:-1])
    else:
        emails_info['sender_name'].append(np.nan)
len(emails_info['sender_name'])
# Out:
# 3977

# %% [markdown]
# ### Info Dates

# %%
#DATES
dates=[]
for i,e in enumerate(contents):
    try:
        dates.append(re.search("Date:.*", e).group())
    except: 
        dates.append("not found")
len(dates)
# Out:
# 3977

# %%
#email date
emails_info['date_sent']=[]
for dat in dates:
    res=re.findall(r"\d+\s\w{3}\s\d+", dat)
    if res:
        emails_info['date_sent'].append(res[0])
    else:
        emails_info['date_sent'].append(np.nan)

len(emails_info['date_sent'])
# Out:
# 3977

# %%
emails_info['time_sent']=[]
for dat in dates:
    res=re.findall(r"\d{2}:\d{2}:\d{2}", dat)
    if res:
        emails_info['time_sent'].append(res[0])
    else:
        emails_info['time_sent'].append(np.nan)

len(emails_info['time_sent'])
# Out:
# 3977

# %% [markdown]
# ### Subject

# %%
subject=[]
for i,e in enumerate(contents):
    try:
        subject.append(re.search("Subject:.*", e).group())
    except: 
        subject.append("not found")
len(subject)
# Out:
# 3977

# %%
emails_info['subject']=[]
for sub in subject:
    res=re.findall(r":.*", sub)
    if res:
        emails_info['subject'].append(res[0][2:])
    else:
        emails_info['subject'].append(np.nan)

len(emails_info['subject'])
# Out:
# 3977

# %% [markdown]
# ### Creating DataFrame

# %%
df=pd.DataFrame(emails_info)
df.isnull().sum()
# Out:
# sender_email    476
# sender_name     837
# date_sent       614
# time_sent       618
# subject          27
# dtype: int64

# %%
df.head()
# Out:
#                    sender_email             sender_name    date_sent  \
# 0   james_ngola2002@maktoob.com     "MR. JAMES NGOLA."   31 Oct 2002
# 1  bensul2004nng@spinfinder.com      "Mr. Ben Suleman"   31 Oct 2002
# 2          obong_715@epatra.com   "PRINCE OBONG ELEME"   31 Oct 2002
# 3          obong_715@epatra.com   "PRINCE OBONG ELEME"   31 Oct 2002
# 4            m_abacha03@www.com        "Maryam Abacha"    1 Nov 2002
#
#   time_sent                                     subject
# 0  02:38:20  URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# 1  05:10:00         URGENT ASSISTANCE /RELATIONSHIP (P)
# 2  22:17:55                             GOOD DAY TO YOU
# 3  22:44:20                             GOOD DAY TO YOU
# 4  01:45:04                     I Need Your Assistance.

# %%
pd.set_option('display.max_rows', 4000)
df
# Out:
# Needed
# 3683  19:52:58             A Very Goodday To You: Response Needed
# 3684  18:03:24                          ASSISTANCE / PARTNERSHIP.
# 3685  16:24:49                                ATTN:URGENT PLEASE.
# 3686  13:07:04  CONFIRM YOUR PAYMENT, I NEED YOUR RESPONSE TO ...
# 3687       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3688       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3689       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3690  17:30:16                             LOW RELATIVE HUMIDITY.
# 3691  20:26:11                              CAN I CONFIDE IN YOU?
# 3692       NaN                       o:MIME-Version:Content-Type;
# 3693  18:40:31                          MAIL FROM MR. ROBERT KING
# 3694  10:04:38                                 URGENT RESPONSE!!!
# 3695  20:26:59                                         Hello dear
# 3696  11:04:31                                      URGENT  REPLY
# 3697  03:18:15            CONFIDENTIAL DEAL,PLEASE GET BACK TO ME
# 3698  21:03:17       Mutual Business co-operation(ATTN: MANAGING
# 3699  01:13:48                                         Hello dear
# 3700  01:14:21                                         Hello dear
# 3701  08:27:09                    LOOKING FORWARD  FOR YOUR REPLY
# 3702  01:50:58                                   FROM:RITA DOINK.
# 3703  15:32:41                               Business proposition
# 3704       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3705  12:37:04      LETTER FROM RACHAEL ONIGA (please reply back)
# 3706       NaN                                          Good News
# 3707  21:02:17           CONFIDENTIAL PROPOSAL [CODE NO: AM-0007]
# 3708  02:46:35             +From Portugal & Urgent Reply Needed +
# 3709  04:29:25                              PLEASE GET BACK TO ME
# 3710  19:53:49                                          GOOD  DAY
# 3711  10:22:56                                          Good News
# 3712  15:34:00                           DEAR BELOVED IN CHRIST ,
# 3713  17:08:37                              Hello Dearest Friend,
# 3714  16:31:09                       URGENT INVESTMENT  PROPOSAL
# 3715  23:40:43                 Capital Investment ( Real Estate )
# 3716  18:32:58  DEAR BELOVED,I am Mrs. Christina Holden. Am ma...
# 3717  15:14:39                                          GOOD DAY.
# 3718  08:12:21          A BUSINESS PROPOSAL FROM MRS. SOSNITSKAYA
# 3719  01:52:13                 URGENT REPLY  NEEDED +27 839470181
# 3720       NaN               =?us-ascii?Q?INVESTMENT=20=20OFFER?=
# 3721  15:24:00                                       JOB OFFER...
# 3722  10:01:04                                       VERY URGENT
# 3723  20:26:42                                 From Frank Hilary.
# 3724  10:41:59                                              Joyce
# 3725  19:43:32                                           Inquiry!
# 3726       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3727       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3728       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3729  20:09:03                             URGENT RESPONSE NEEDED
# 3730  16:38:00                                FROM Mr.JEFFRY MURD
# 3731  02:28:45                        RE: NOTIFICATION OF BEQUEST
# 3732  09:26:41      I NEED YOUR URGENT REPLY  CONFIDENTIAL PLEASE
# 3733       NaN                     =?iso-8859-1?Q?Investment=2E?=
# 3734  20:34:52                    FROM, LAWSON (URGENT PROPOSAL).
# 3735  16:33:32                                         WITH TRUST
# 3736       NaN                                     <kein Betreff>
# 3737       NaN                                     <kein Betreff>
# 3738  17:34:58                                           Good Day
# 3739       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3740  21:05:28                                              hello
# 3741  04:22:00                              I AWAIT YOUR RESPONSE
# 3742  12:34:09                    FROM THE DESK OF Dr.Frank West.
# 3743  08:20:20                               Business Partnership
# 3744  18:13:59                                       DEAR FRIEND,
# 3745  15:41:00                             From Mr.Charles Greene
# 3746  10:37:33   REPRESENTATIVE NEEDED........................!!!
# 3747  05:52:35                YOUR  COMPENSATIONS MONEY IS  READY
# 3748  08:28:36  CONTACT MY P/A FOR YOUR CERTIFIED CASHIER CHEQ...
# 3749       NaN                       o:MIME-Version:Content-Type;
# 3750  05:43:43                                                NaN
# 3751       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3752  00:45:58                                              REPLY
# 3753  09:21:57  From: Barrister Gareth Jones Tel:+44 703 184 4817
# 3754  10:00:43       I AM URGENTLY WAITING FOR YOUR CALL OR EMAIL
# 3755  06:08:41                           Regarding Mr. James Cole
# 3756  14:06:40                           &^ PLEASE READ CAREFULLY
# 3757  23:53:21                           From Mrs. G. Ajith Kumar
# 3758  10:23:18             From The Desk Of  MUSTAFA BRUNU (Esq).
# 3759  22:31:18                                       VERY URGENT,
# 3760  13:36:14                           URGENT AND CONFIDENCTIAL
# 3761       NaN                                    My time of need
# 3762  09:39:45                                        Please read
# 3763  14:55:39                               MY DEAR RESPECTFUL.
# 3764  14:55:39                               MY DEAR RESPECTFUL.
# 3765  19:07:18                                          GREETINGS
# 3766  09:56:50                                 FROM: DAVID PEDRO.
# 3767  17:45:52                   A  BUSINESS PROPOSAL FROM RUSSIA
# 3768  19:52:39                                      From JONATHAN
# 3769  10:35:46                     please read and get back to me
# 3770  12:51:50                      + CAN YOU HELP ME WITH THIS +
# 3771  08:20:12             "MY GOOD WILL" THANK YOU AS YOU REPLY.
# 3772  16:20:00                                       CONFIDENTIAL
# 3773  09:12:08  From: Barrister Gareth Jones Mobile +44 703 18...
# 3774  12:40:27                   FROM  EDWARD  MOORE & ASSOCIATES
# 3775  02:11:05                             Urgent Response Needed
# 3776  15:25:03                                      SVP AIDEZ MOI
# 3777  08:13:11            From: Edward Moore & Associates(Urgent)
# 3778  08:37:22            From: Edward Moore & Associates(Urgent)
# 3779  09:35:45            From: Edward Moore & Associates(Urgent)
# 3780  10:21:10            From: Edward Moore & Associates(Urgent)
# 3781       NaN          Greetings from barrister Robert Williams,
# 3782  07:56:01                                                NaN
# 3783  21:02:05  From Michael Jones (Contact Me Back If Interes...
# 3784  19:16:50                       GREETINGS FROM KOUTABA  JEAN
# 3785  17:23:30                                        Good day!!!
# 3786  04:29:31                            URGENT AND CONFIDENTIAL
# 3787       NaN          Greetings from barrister Robert Williams,
# 3788  09:32:32                                                NaN
# 3789  12:03:37                   FROM  EDWARD  MOORE & ASSOCIATES
# 3790  08:04:56                                             URGENT
# 3791  11:50:37                               FROM: MR.COLIN SHAND
# 3792  15:49:47                                   Mr Richard Bongo
# 3793  15:49:57                                   Mr Richard Bongo
# 3794  15:40:45                       GREETINGS FROM KOUTABA  JEAN
# 3795  16:31:06                  I am waiting to receive your mail
# 3796  20:48:11                               I GOT YOUR CONTACT..
# 3797  05:47:04                             Re: Your Kind Response
# 3798  18:18:49       Good day to you. Please your reply expected.
# 3799  01:59:36             Trusting to hear from you immediately.
# 3800  07:08:50                              MY SECOND MAIL TO YOU
# 3801  07:08:50                              MY SECOND MAIL TO YOU
# 3802  19:46:58                                           GOOD DAY
# 3803  19:20:48         TREAT VERY CONFIDENTIAL & URGENT RESPONSE.
# 3804  10:41:58                   A  BUSINESS PROPOSAL FROM RUSSIA
# 3805  10:38:31                                                NaN
# 3806  06:39:30                          URGENT BUSINESS PROPOSAL
# 3807  12:26:56                                BUSSINESS OFFER!!!!
# 3808  13:01:58                                        FROM LARISA
# 3809  19:21:40                                     GET BACK TO ME
# 3810       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3811  16:12:29                             FROM DR. PAUL A . SULE
# 3812  08:06:56                               FROM:MR JOHN ALISON.
# 3813  06:04:58        I Feel Great For Investment In Your Country
# 3814  11:26:14                                    MY PROPOSITION:
# 3815  10:02:51                             From: Mr. Paul Baloyi.
# 3816  10:02:51                             From: Mr. Paul Baloyi.
# 3817       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3818  23:43:57                                       DEAR FRIEND,
# 3819  23:43:57                                       DEAR FRIEND,
# 3820  12:12:39                         URGENT BUSINESS INVITATION
# 3821  14:59:04                                          From Fred
# 3822  11:37:15                                          REPLY ME.
# 3823  12:08:19                                VERY VERY IMPORTANT
# 3824  08:18:04                           How Are You Doing Today?
# 3825  09:59:38  *********ADD MORE TO YOUR INCOME WITH EASE****...
# 3826  07:38:30                                     PAYMENT UPDATE
# 3827  13:41:11                                       Dear Partner
# 3828  14:41:02                           How Are You Doing Today?
# 3829  19:52:49                          From Mrs Theresa Coleman,
# 3830       NaN                       o:MIME-Version:Content-Type;
# 3831  04:39:33                            Partnership Proposal!!!
# 3832  05:38:00                             FROM MR.MAZURI MARTINS
# 3833  00:52:57                                            WAITING
# 3834  14:11:30                                        Salutation,
# 3835  14:14:41                                        Salutation,
# 3836  13:55:38                              CONFIDENTIAL PROPOSAL
# 3837  13:34:02                  YOUR RESPONSE IS URGENTLY NEEDED.
# 3838  22:14:34              Internal Revenue Service - Tax Refund
# 3839       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3840       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3841  07:08:33                                Await Your Position
# 3842  07:17:54                                Await Your Position
# 3843  02:21:44         VERY URGENT AND EMERGENCY RESPONSE........
# 3844  06:24:49                                  HELLO DEAR FRIEND
# 3845       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3846  20:12:08                       Your kind attention needed.
# 3847  10:44:14                                        Salutation,
# 3848  15:15:39                                      Dear Friend
# 3849  23:03:44                                     GET BACK TO ME
# 3850       NaN             ATTN:Investors Partnership From Mr.Tim
# 3851  22:14:46                      RE: YOUR OUTSTANDING PAYMENT.
# 3852  16:06:52                                    Personal Offer.
# 3853       NaN                              FROM MR. MARTINS AKIM
# 3854  15:03:36                            For your kind attention
# 3855  15:03:36                            For your kind attention
# 3856  16:57:01                                MUTUAL PARTNERSHIP.
# 3857       NaN                 From:Evangelist Lindy Mike(Widow).
# 3858       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3859  02:02:03                    From: Edward Moore & Associates
# 3860  05:56:29                    From: Edward Moore & Associates
# 3861  09:10:42                   FROM THE DESK OF : BJSRI BUDAK,
# 3862  11:06:53                                urgent transaction.
# 3863  17:56:43                              FROM: Mr.Gary William
# 3864       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3865  07:51:04                       REPLY ME.From Robin Shephard
# 3866  16:02:00                                         Greetings!
# 3867  04:00:06                    Request to do business with you
# 3868  09:04:40  =?windows-1256?Q?I_AM_WAITING_TO_RECEIVE_YOUR_...
# 3869       NaN  =?iso-8859-1?Q?CONTACT=20THE=20DELIVERY=20COMP...
# 3870  16:28:48                                          MOI CHER.
# 3871  18:55:17                                     ATT: Proposal.
# 3872  15:12:21                         From Mrs Farah al-hashemi.
# 3873  15:12:23                         From Mrs Farah al-hashemi.
# 3874  02:26:58                                             FAVOUR
# 3875  17:25:18                         CONFIDENTIAL PROPOSAL FROM
# 3876  11:42:02                             From Mike Kone To You,
# 3877  12:17:29                                           GOOD DAY
# 3878  23:44:24                      RECEIVE YOUR CONTRACT PAYMENT
# 3879  20:10:19                                   FROM : JOHN ABOH
# 3880       NaN                       o:MIME-Version:Content-Type;
# 3881  07:56:54                 YOUR CONTRACT / INHERITANCE CLAIM.
# 3882  07:56:55                 YOUR CONTRACT / INHERITANCE CLAIM.
# 3883  04:01:25                                        DEAR FRIEND
# 3884  20:05:05                                RE BANKING BUSINESS
# 3885  13:49:29                                             TRUST
# 3886       NaN               Transfer of Title Enquiry: Hsbc Bank
# 3887  18:24:02  Re: Trusted Beneficiary Needed by Manager Lena...
# 3888       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3889       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3890  03:29:36                             TRANSFER NEGOTIATION!!
# 3891  14:16:31                            FROM MISS ALIMA KAMOKAI
# 3892  12:40:39                                      MY GOOD WILL.
# 3893       NaN                               MY FIRST OPPORTUNITY
# 3894  15:46:06                      AWAITING  FOR  YOUR  RESPONSE
# 3895  15:32:54   Yahoo! Address Book Contacts (mrsrose_mkama_200)
# 3896       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3897       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3898  07:57:00                    CONFIRM SHIPMENT OF DUE PAYMENT
# 3899  13:51:02                                          Bonjour,
# 3900  02:46:05   =?ISO-8859-1?Q?BOA=AE?= Information Is Outdated.
# 3901  04:48:49                                           GOOD DAY
# 3902  15:21:29  RE:CHANGE OF ACCOUNT PARTICULARS ON YOUR BENEF...
# 3903       NaN                                         Greetings!
# 3904  15:14:12                           IMPORTANT URGENT REQUEST
# 3905       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3906       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3907  14:03:12                I AM WAITING FOR YOUR URGENT REPLY.
# 3908  16:40:12            YOUR URGENT RESPONSE IS HIGHLY NEEDED!!
# 3909  15:54:16  From:Mrs Farah al-Hashemi :I will appreciate y...
# 3910  15:49:02                           urgent and confidential.
# 3911  21:19:21     From Susan and Williams/Appeal for Assistance.
# 3912  18:38:08                    CONFIDENTIAL URGENT PROPOSAL.
# 3913  09:41:35                                     ATT: Sir/Madam
# 3914  01:36:04  From:Mrs Farah al-Hashemi :I will appreciate y...
# 3915  03:40:06                                       private mail
# 3916  03:40:06                                       private mail
# 3917  02:20:56                 DEAR GOOD FRIEND PLEASE REPLY BACK
# 3918  18:04:33                                         GOOD  NEWS
# 3919  22:21:21                                       confidentiel
# 3920  12:20:43                                              Dear,
# 3921  12:56:58                   URGENT CALL FROM MR ADAMS KABORA
# 3922  13:35:23                   URGENT CALL FROM MR ADAMS KABORA
# 3923  09:52:11                                              HELLO
# 3924       NaN                       o:MIME-Version:Content-Type;
# 3925  08:23:26  GOOD MORNING AND HAPPY TO MEET YOUR EMAIL PROF...
# 3926  09:40:34                                   CONTACT THEM NOW
# 3927  12:22:47               Job Opportunity (work while at home)
# 3928       NaN                       o:MIME-Version:Content-Type;
# 3929       NaN                           Do not hestitate to Read
# 3930  07:13:56                 REQUEST FOR YOUR URGENT ASSISTANCE
# 3931       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3932  20:54:03        Read Carefully Please, Company Agent Needed
# 3933  08:57:41                            Partnership Proposal!!!
# 3934  10:07:27                  FROM: MISS FELISSA JENNY HARRISON
# 3935  14:15:23                        ATTN:DID YOU GET MY E-MAIL?
# 3936  09:53:04                                       JOB OFFER!!!
# 3937  09:53:04                                       JOB OFFER!!!
# 3938  02:15:29                                       Attn Please,
# 3939  22:08:35                           URGENT BUSINESS RESPONSE
# 3940       NaN                       o:MIME-Version:Content-Type;
# 3941  01:05:19                                        INHERITANCE
# 3942  14:08:53                               FROM CHARLES ANTHONY
# 3943       NaN  o:MIME-Version:Content-Type:Content-Transfer-E...
# 3944  15:06:15                              !WORK WITH ME URGENT!
# 3945  11:39:40                                MR. KENNETH MASHABA
# 3946  03:21:23                                        PROPOSITION
# 3947  14:23:05                            Urgent Attention " Now"
# 3948  10:22:58                                        PROPOSITION
# 3949  17:41:23                            FROM MRS   ANNAH  KURGA
# 3950  22:05:01                             URGENT RESPONSE NEEDED
# 3951  16:18:54                                       BE OUR AGENT
# 3952  14:50:14                         RE: PLEASE CONTACT ME SOON
# 3953  21:18:23                                         THE FORMAT
# 3954  15:51:17                               FROM  JAMES  BONGANI
# 3955  13:54:13                              PLEASE REPLY URGENTLY
# 3956  15:41:26                                             HELLO
# 3957       NaN  HOW WOULD YOU USE MY FUND TO HELP THE LESS PRI...
# 3958  18:51:18  CASTLE LAW CHAMBERS (urgent reply, can i trust...
# 3959  05:09:34     CAN YOU WORK WITH  ME ON BEHALF OF MY FATHER?.
# 3960  13:52:17                                    PRIVATE MESSAGE
# 3961  20:54:44                           URGENT BUSINESS PROPOSAL
# 3962  09:03:37                     ASSALAM-U-ALAIKUM REPLY URGENT
# 3963  17:18:31                                          RE: REPLY
# 3964  09:13:23                      CONSINDER MY URGENT REQUEST.
# 3965  18:39:27                                   Attention please
# 3966  21:07:18                                FROM MR HENRY ALLEN
# 3967  09:44:16                         Re: eMAIL From John Davids
# 3968  10:05:03                         Re: eMAIL From John Davids
# 3969  23:42:19                              My Beloved In Christ.
# 3970  06:08:28                              REF: 14TH SEPT., 2007
# 3971  06:07:02                    From: Dr. Jackson Gaius-Obaseki
# 3972       NaN  =?iso-8859-1?Q?CONTACT=20GLOBAL=20MAX=20SHIPIN...
# 3973  22:28:11                                   TREAT AS URGENT.
# 3974  10:54:53   From Dr Usman Ibrahim / Mr Wahid Yoffe property.
# 3975  00:52:16                            My Beloved In Christ.
# 3976  13:41:32                                          ATTENTION

# %%
nigerianfilter = df.loc[df['sender_email'].str.contains("nig \w{1,}/", case=False)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-aa06b9b94b39> in <module>
# ----> 1 nigerianfilter = df.loc[df['sender_email'].str.contains("nig \w{1,}/", case=False)]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1101             self._validate_key(key, axis)
#    1102             return self._get_slice_axis(key, axis=axis)
# -> 1103         elif com.is_bool_indexer(key):
#    1104             return self._getbool_axis(key, axis=axis)
#    1105         elif is_list_like_indexer(key):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     112                     # Don't raise on e.g. ["A", "B", np.nan], see
#     113                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 114                     raise ValueError(na_msg)
#     115                 return False
#     116             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# ### ¡Now you can start your analysis!
