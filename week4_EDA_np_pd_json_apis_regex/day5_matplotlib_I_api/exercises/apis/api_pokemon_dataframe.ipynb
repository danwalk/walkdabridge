# %% [markdown]
# ### Ejercicio 1
#
# A partir de la API de Pokemon, se pide generar un DataFrame como el de la imagen con las columnas:
#
# - **"height","id","order","weight","types"**
#
# ### Ejercicio 2
#
# ¿Has visto que dentro del DataFrame la columna "types" hay diccionarios? Se pide agregar, por cada pokemon, las columnas necesarias al DataFrame para albergar toda la información de "types" (solo las keys)
#
# ![](df_pk.PNG)

# %%
import json
import requests

import pandas as pd
from pandas.io.json import json_normalize

# %%
poke_json = requests.get("https://pokeapi.co/api/v2/pokemon").json()
poke_json
# Out:
# {'count': 1118,
#  'next': 'https://pokeapi.co/api/v2/pokemon?offset=20&limit=20',
#  'previous': None,
#  'results': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#   {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#   {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#   {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#   {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#   {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#   {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#   {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
# ...

# %%
#json_normalize(poke_json)

pd.json_normalize(poke_json)
# Out:
#    count                                               next previous  \
# 0   1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
#
#                                              results
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...

# %%
df = pd.DataFrame(poke_json)
df
# Out:
#     count                                               next previous  \
# 0    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 1    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 2    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 3    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 4    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 5    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 6    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 7    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 8    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 9    1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 10   1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 11   1118  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# ...

# %%
df2 = df['results']
df2
# Out:
# 0     {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1     {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 2     {'name': 'venusaur', 'url': 'https://pokeapi.c...
# 3     {'name': 'charmander', 'url': 'https://pokeapi...
# 4     {'name': 'charmeleon', 'url': 'https://pokeapi...
# 5     {'name': 'charizard', 'url': 'https://pokeapi....
# 6     {'name': 'squirtle', 'url': 'https://pokeapi.c...
# 7     {'name': 'wartortle', 'url': 'https://pokeapi....
# 8     {'name': 'blastoise', 'url': 'https://pokeapi....
# 9     {'name': 'caterpie', 'url': 'https://pokeapi.c...
# 10    {'name': 'metapod', 'url': 'https://pokeapi.co...
# 11    {'name': 'butterfree', 'url': 'https://pokeapi...
# 12    {'name': 'weedle', 'url': 'https://pokeapi.co/...
# 13    {'name': 'kakuna', 'url': 'https://pokeapi.co/...
# 14    {'name': 'beedrill', 'url': 'https://pokeapi.c...
# 15    {'name': 'pidgey', 'url': 'https://pokeapi.co/...
# 16    {'name': 'pidgeotto', 'url': 'https://pokeapi....
# ...

# %%
df3 = pd.DataFrame(df2)
df3
# Out:
#                                               results
# 0   {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1   {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 2   {'name': 'venusaur', 'url': 'https://pokeapi.c...
# 3   {'name': 'charmander', 'url': 'https://pokeapi...
# 4   {'name': 'charmeleon', 'url': 'https://pokeapi...
# 5   {'name': 'charizard', 'url': 'https://pokeapi....
# 6   {'name': 'squirtle', 'url': 'https://pokeapi.c...
# 7   {'name': 'wartortle', 'url': 'https://pokeapi....
# 8   {'name': 'blastoise', 'url': 'https://pokeapi....
# 9   {'name': 'caterpie', 'url': 'https://pokeapi.c...
# 10  {'name': 'metapod', 'url': 'https://pokeapi.co...
# 11  {'name': 'butterfree', 'url': 'https://pokeapi...
# 12  {'name': 'weedle', 'url': 'https://pokeapi.co/...
# 13  {'name': 'kakuna', 'url': 'https://pokeapi.co/...
# 14  {'name': 'beedrill', 'url': 'https://pokeapi.c...
# 15  {'name': 'pidgey', 'url': 'https://pokeapi.co/...
# ...

# %%
for a in df3['results']:
    print(a['name'])
# Out:
# bulbasaur
# ivysaur
# venusaur
# charmander
# charmeleon
# charizard
# squirtle
# wartortle
# blastoise
# caterpie
# metapod
# butterfree
# weedle
# kakuna
# beedrill
# pidgey
# pidgeotto
# pidgeot
# rattata
# raticate

# %%
df4 = pd.DataFrame(poke_json["results"])
df4
# Out:
#           name                                    url
# 0    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/
# 1      ivysaur   https://pokeapi.co/api/v2/pokemon/2/
# 2     venusaur   https://pokeapi.co/api/v2/pokemon/3/
# 3   charmander   https://pokeapi.co/api/v2/pokemon/4/
# 4   charmeleon   https://pokeapi.co/api/v2/pokemon/5/
# 5    charizard   https://pokeapi.co/api/v2/pokemon/6/
# 6     squirtle   https://pokeapi.co/api/v2/pokemon/7/
# 7    wartortle   https://pokeapi.co/api/v2/pokemon/8/
# 8    blastoise   https://pokeapi.co/api/v2/pokemon/9/
# 9     caterpie  https://pokeapi.co/api/v2/pokemon/10/
# 10     metapod  https://pokeapi.co/api/v2/pokemon/11/
# 11  butterfree  https://pokeapi.co/api/v2/pokemon/12/
# 12      weedle  https://pokeapi.co/api/v2/pokemon/13/
# 13      kakuna  https://pokeapi.co/api/v2/pokemon/14/
# 14    beedrill  https://pokeapi.co/api/v2/pokemon/15/
# 15      pidgey  https://pokeapi.co/api/v2/pokemon/16/
# ...

# %%
for a in df4['url']:
    peticion_api_url = requests.get(url).json()
    print(peticion_api_url)
# Out:
#  'https://pokeapi.co/api/v2/pokemon/14/'}, {'name': 'beedrill', 'url': 'https://pokeapi.co/api/v2/pokemon/15/'}, {'name': 'pidgey', 'url': 'https://pokeapi.co/api/v2/pokemon/16/'}, {'name': 'pidgeotto', 'url': 'https://pokeapi.co/api/v2/pokemon/17/'}, {'name': 'pidgeot', 'url': 'https://pokeapi.co/api/v2/pokemon/18/'}, {'name': 'rattata', 'url': 'https://pokeapi.co/api/v2/pokemon/19/'}, {'name': 'raticate', 'url': 'https://pokeapi.co/api/v2/pokemon/20/'}]}
# ...

# %%
dic = df4.to_dict(orient='records')
dic
# Out:
# [{'name': 'bulbasaur', 'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#  {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#  {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#  {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#  {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#  {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#  {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#  {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#  {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#  {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#  {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
#  {'name': 'butterfree', 'url': 'https://pokeapi.co/api/v2/pokemon/12/'},
#  {'name': 'weedle', 'url': 'https://pokeapi.co/api/v2/pokemon/13/'},
# ...

# %%
diccionario_pokemons_url = {}
for i, e in enumerate(dic):
    nombre_pokemon = dic[i]["name"]
    url_pokemon = dic[i]["url"]
    diccionario_pokemons_url[nombre_pokemon] = url_pokemon

diccionario_pokemons_url
# Out:
# {'bulbasaur': 'https://pokeapi.co/api/v2/pokemon/1/',
#  'ivysaur': 'https://pokeapi.co/api/v2/pokemon/2/',
#  'venusaur': 'https://pokeapi.co/api/v2/pokemon/3/',
#  'charmander': 'https://pokeapi.co/api/v2/pokemon/4/',
#  'charmeleon': 'https://pokeapi.co/api/v2/pokemon/5/',
#  'charizard': 'https://pokeapi.co/api/v2/pokemon/6/',
#  'squirtle': 'https://pokeapi.co/api/v2/pokemon/7/',
#  'wartortle': 'https://pokeapi.co/api/v2/pokemon/8/',
#  'blastoise': 'https://pokeapi.co/api/v2/pokemon/9/',
#  'caterpie': 'https://pokeapi.co/api/v2/pokemon/10/',
#  'metapod': 'https://pokeapi.co/api/v2/pokemon/11/',
#  'butterfree': 'https://pokeapi.co/api/v2/pokemon/12/',
#  'weedle': 'https://pokeapi.co/api/v2/pokemon/13/',
#  'kakuna': 'https://pokeapi.co/api/v2/pokemon/14/',
#  'beedrill': 'https://pokeapi.co/api/v2/pokemon/15/',
#  'pidgey': 'https://pokeapi.co/api/v2/pokemon/16/',
#  'pidgeotto': 'https://pokeapi.co/api/v2/pokemon/17/',
# ...

# %%
abilities = ['name', 'url', 'height', 'id', 'order', 'weight', 'types']
pokemon = {}
pdic = {}
counter = 0
for nombre_pokemon, url in diccionario_pokemons_url.items():
    counter += 1    
    t = requests.get(url).json()
    pokemon['name'] = t['name']
    pokemon['url'] = url
    pokemon['height'] = t['height']
    pokemon['id'] = t['id']
    pokemon['order'] = t['order']
    pokemon['weight'] = t['weight']
    pokemon['types'] = t['types']
    pdic[counter] = pokemon
    pokemon = {}
    

print(pdic)
# Out:
# {1: {'name': 'bulbasaur', 'url': 'https://pokeapi.co/api/v2/pokemon/1/', 'height': 7, 'id': 1, 'order': 1, 'weight': 69, 'types': [{'slot': 1, 'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}, {'slot': 2, 'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]}, 2: {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/', 'height': 10, 'id': 2, 'order': 2, 'weight': 130, 'types': [{'slot': 1, 'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}, {'slot': 2, 'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]}, 3: {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/', 'height': 20, 'id': 3, 'order': 3, 'weight': 1000, 'types': [{'slot': 1, 'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}, {'slot': 2, 'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]}, 4: {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/', 'height': 6, 'id
# ...

# %%
fg = pd.DataFrame(pdic)
fg
# Out:
#                                                        1   \
# name                                            bulbasaur
# url                  https://pokeapi.co/api/v2/pokemon/1/
# height                                                  7
# id                                                      1
# order                                                   1
# weight                                                 69
# types   [{'slot': 1, 'type': {'name': 'grass', 'url': ...
#
#                                                        2   \
# name                                              ivysaur
# url                  https://pokeapi.co/api/v2/pokemon/2/
# height                                                 10
# id                                                      2
# order                                                   2
# weight                                                130
# types   [{'slot': 1, 'type': {'name': 'grass', 'url': ...
#
# ...

# %%
ss = fg.T
ss
# Out:
#           name                                    url height  id order weight  \
# 1    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/      7   1     1     69
# 2      ivysaur   https://pokeapi.co/api/v2/pokemon/2/     10   2     2    130
# 3     venusaur   https://pokeapi.co/api/v2/pokemon/3/     20   3     3   1000
# 4   charmander   https://pokeapi.co/api/v2/pokemon/4/      6   4     5     85
# 5   charmeleon   https://pokeapi.co/api/v2/pokemon/5/     11   5     6    190
# 6    charizard   https://pokeapi.co/api/v2/pokemon/6/     17   6     7    905
# 7     squirtle   https://pokeapi.co/api/v2/pokemon/7/      5   7    10     90
# 8    wartortle   https://pokeapi.co/api/v2/pokemon/8/     10   8    11    225
# 9    blastoise   https://pokeapi.co/api/v2/pokemon/9/     16   9    12    855
# 10    caterpie  https://pokeapi.co/api/v2/pokemon/10/      3  10    14     29
# 11     metapod  https://pokeapi.co/api/v2/pokemon/11/      7  11    15     99
# ...

# %%
ss.types[:1][:1 :]
# Out:
# 1    [{'slot': 1, 'type': {'name': 'grass', 'url': ...
# Name: types, dtype: object

# %%
#def unpack(df, column, fillna=None):
    #ret = None
    #ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems())).fillna(fillna)], axis=1)
    #del ret[column]
    #eturn ret

#unpack(ss, 'types', 0)
#for row in ss.index:
    #print(row)
#for i in ss.index:
    #ss['slot'] = ss["types"][i][0]['slot']
    #ss['typesname'] = ss["types"][i][0]['type']['name']
# Out:
#           name                                    url height  id order weight  \
# 1    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/      7   1     1     69
# 2      ivysaur   https://pokeapi.co/api/v2/pokemon/2/     10   2     2    130
# 3     venusaur   https://pokeapi.co/api/v2/pokemon/3/     20   3     3   1000
# 4   charmander   https://pokeapi.co/api/v2/pokemon/4/      6   4     5     85
# 5   charmeleon   https://pokeapi.co/api/v2/pokemon/5/     11   5     6    190
# 6    charizard   https://pokeapi.co/api/v2/pokemon/6/     17   6     7    905
# 7     squirtle   https://pokeapi.co/api/v2/pokemon/7/      5   7    10     90
# 8    wartortle   https://pokeapi.co/api/v2/pokemon/8/     10   8    11    225
# 9    blastoise   https://pokeapi.co/api/v2/pokemon/9/     16   9    12    855
# 10    caterpie  https://pokeapi.co/api/v2/pokemon/10/      3  10    14     29
# 11     metapod  https://pokeapi.co/api/v2/pokemon/11/      7  11    15     99
# ...

# %%
#ss["types"][1][0]['type']['name']
ss.types.1
# Out:
#   File "<ipython-input-236-2cbfd03bfa4f>", line 2
#     ss.types.1
#              ^
# SyntaxError: invalid syntax

# %%
# Out:
# 1     [{'slot': 1, 'type': {'name': 'grass', 'url': ...
# 2     [{'slot': 1, 'type': {'name': 'grass', 'url': ...
# 3     [{'slot': 1, 'type': {'name': 'grass', 'url': ...
# 4     [{'slot': 1, 'type': {'name': 'fire', 'url': '...
# 5     [{'slot': 1, 'type': {'name': 'fire', 'url': '...
# 6     [{'slot': 1, 'type': {'name': 'fire', 'url': '...
# 7     [{'slot': 1, 'type': {'name': 'water', 'url': ...
# 8     [{'slot': 1, 'type': {'name': 'water', 'url': ...
# 9     [{'slot': 1, 'type': {'name': 'water', 'url': ...
# 10    [{'slot': 1, 'type': {'name': 'bug', 'url': 'h...
# 11    [{'slot': 1, 'type': {'name': 'bug', 'url': 'h...
# 12    [{'slot': 1, 'type': {'name': 'bug', 'url': 'h...
# 13    [{'slot': 1, 'type': {'name': 'bug', 'url': 'h...
# 14    [{'slot': 1, 'type': {'name': 'bug', 'url': 'h...
# 15    [{'slot': 1, 'type': {'name': 'bug', 'url': 'h...
# 16    [{'slot': 1, 'type': {'name': 'normal', 'url':...
# 17    [{'slot': 1, 'type': {'name': 'normal', 'url':...
# ...

# %%
gg = ss.to_dict(orient='records')
gg
# Out:
# [{'name': 'bulbasaur',
#   'url': 'https://pokeapi.co/api/v2/pokemon/1/',
#   'height': 7,
#   'id': 1,
#   'order': 1,
#   'weight': 69,
#   'types': [{'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#    {'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'name': 'ivysaur',
#   'url': 'https://pokeapi.co/api/v2/pokemon/2/',
#   'height': 10,
#   'id': 2,
#   'order': 2,
#   'weight': 130,
#   'types': [{'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#    {'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'name': 'venusaur',
#   'url': 'https://pokeapi.co/api/v2/pokemon/3/',
#   'height': 20,
#   'id': 3,
#   'order': 3,
#   'weight': 1000,
#   'types': [{'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#    {'slot': 2,
# ...

# %%
for i in enumerate(gg):
    gg[i]['typesslot'] = gg[0]['types'][0]['slot']
    gg[i]['typename'] = gg[0]['types'][0]['type']['name']
    gg[i]['typename'] = gg[0]['types'][0]['type']['url']
gg
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-260-441426ce33a4> in <module>
#       1 for i in enumerate(gg):
# ----> 2     gg[i]['typesslot'] = gg[0]['types'][0]['slot']
#       3     gg[i]['typename'] = gg[0]['types'][0]['type']['name']
#       4     gg[i]['typename'] = gg[0]['types'][0]['type']['url']
#       5 gg
#
# TypeError: list indices must be integers or slices, not tuple

# %%
gg[0]['types'][0]['type']['url']
# Out:
# 'https://pokeapi.co/api/v2/type/12/'

# %%
counter = 0
for i in gg:
    gg[counter]['typesslot'] = gg[counter]['types'][0]['slot']
    gg[counter]['typename'] = gg[counter]['types'][0]['type']['name']
    gg[counter]['typeurl'] = gg[counter]['types'][0]['type']['url']
    counter +=1

gg
# Out:
# [{'name': 'bulbasaur',
#   'url': 'https://pokeapi.co/api/v2/pokemon/1/',
#   'height': 7,
#   'id': 1,
#   'order': 1,
#   'weight': 69,
#   'types': [{'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#    {'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}],
#   'typesslot': 1,
#   'typename': 'grass',
#   'typeurl': 'https://pokeapi.co/api/v2/type/12/'},
#  {'name': 'ivysaur',
#   'url': 'https://pokeapi.co/api/v2/pokemon/2/',
#   'height': 10,
#   'id': 2,
#   'order': 2,
#   'weight': 130,
#   'types': [{'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#    {'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}],
#   'typesslot': 1,
#   'typename': 'grass',
#   'typeurl': 'https://pokeapi.co/api/v2/type/12/'},
#  {'name': 'venusaur',
#   'url': 'https://pokeapi.co/api/v2/pokemon/3/',
#   'height': 20,
#   'id': 3,
# ...

# %%
#exercise1
ss
# Out:
#           name                                    url height  id order weight  \
# 1    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/      7   1     1     69
# 2      ivysaur   https://pokeapi.co/api/v2/pokemon/2/     10   2     2    130
# 3     venusaur   https://pokeapi.co/api/v2/pokemon/3/     20   3     3   1000
# 4   charmander   https://pokeapi.co/api/v2/pokemon/4/      6   4     5     85
# 5   charmeleon   https://pokeapi.co/api/v2/pokemon/5/     11   5     6    190
# 6    charizard   https://pokeapi.co/api/v2/pokemon/6/     17   6     7    905
# 7     squirtle   https://pokeapi.co/api/v2/pokemon/7/      5   7    10     90
# 8    wartortle   https://pokeapi.co/api/v2/pokemon/8/     10   8    11    225
# 9    blastoise   https://pokeapi.co/api/v2/pokemon/9/     16   9    12    855
# 10    caterpie  https://pokeapi.co/api/v2/pokemon/10/      3  10    14     29
# 11     metapod  https://pokeapi.co/api/v2/pokemon/11/      7  11    15     99
# ...

# %%
#exercise2
final = pd.DataFrame(gg)
final
final.drop(columns='types')
# Out:
#           name                                    url  height  id  order  \
# 0    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/       7   1      1
# 1      ivysaur   https://pokeapi.co/api/v2/pokemon/2/      10   2      2
# 2     venusaur   https://pokeapi.co/api/v2/pokemon/3/      20   3      3
# 3   charmander   https://pokeapi.co/api/v2/pokemon/4/       6   4      5
# 4   charmeleon   https://pokeapi.co/api/v2/pokemon/5/      11   5      6
# 5    charizard   https://pokeapi.co/api/v2/pokemon/6/      17   6      7
# 6     squirtle   https://pokeapi.co/api/v2/pokemon/7/       5   7     10
# 7    wartortle   https://pokeapi.co/api/v2/pokemon/8/      10   8     11
# 8    blastoise   https://pokeapi.co/api/v2/pokemon/9/      16   9     12
# 9     caterpie  https://pokeapi.co/api/v2/pokemon/10/       3  10     14
# 10     metapod  https://pokeapi.co/api/v2/pokemon/11/       7  11     15
# 11  butterfree  https://pokeapi.co/api/v2/pokemon/12/      11  12     16
# ...
