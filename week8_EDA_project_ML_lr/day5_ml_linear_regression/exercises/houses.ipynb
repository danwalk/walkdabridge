# %% [markdown]
# ### Se pide:
#
# A partir del archivo "USA_Housing.csv", realizar la regresión lineal entre cada columna numérica con la columna 'price'.
#
# Cuando existe una columna(variable) que es la que se quiere comparar, se le llama 'target'.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics


df = pd.read_csv("../data/USA_Housing.csv")

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
X = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
y = df['Price']
y = y.to_numpy()

# %%
aai = df['Avg. Area Income']

# %%
aai = aai.to_numpy()

# %%
aai
# Out:
# array([79545.45857432, 79248.64245483, 61287.06717866, ...,
#        63390.6868855 , 68001.33123509, 65510.58180367])

# %%
aaimod = LinearRegression(n_jobs=-1)

# %%
aai = aai.reshape(-1, 1)

# %%
aai.shape
# Out:
# (5000, 1)

# %%
y = y.reshape(-1, 1)

# %%
y.shape
# Out:
# (5000, 1)

# %%
aai_train, aai_test, y_train, y_test = train_test_split(aai, y, test_size=0.2, random_state=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2b79ff96f37b> in <module>
# ----> 1 aai_train, aai_test, y_train, y_test = train_test_split(aai, y, test_size=0.2, random_state=None)
#
# NameError: name 'train_test_split' is not defined

# %%
aaimod.fit(aai, y)
# Out:
# LinearRegression(n_jobs=-1)

# %%
plt.scatter(aai, y, color='g')
plt.plot(aai, aaimod.predict(aai), color='red')

# %%
aaha = df['Avg. Area House Age']
aaha = aaha.to_numpy()
aaha = aaha.reshape(-1, 1)
aahamod = LinearRegression(n_jobs=-1)
aaha_train, aaha_test, y_train, y_test = train_test_split(aaha, y, test_size=0.2, random_state=None)
aahamod.fit(aaha, y)
plt.scatter(aaha, y, color='pink')
plt.plot(aaha, aahamod.predict(aaha), color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65817b232df9> in <module>
# ----> 1 aaha = df['Avg. Area House Age']
#       2 aaha = aaha.to_numpy()
#       3 aaha = aaha.reshape(-1, 1)
#       4 aahamod = LinearRegression(n_jobs=-1)
#       5 aaha_train, aaha_test, y_train, y_test = train_test_split(aaha, y, test_size=0.2, random_state=None)
#
# NameError: name 'df' is not defined

# %%
aanr = df['Avg. Area Number of Rooms']
aanr = aanr.to_numpy()
aanr = aanr.reshape(-1, 1)
aanrmod = LinearRegression(n_jobs=-1)
aanr_train, aanr_test, y_train, y_test = train_test_split(aanr, y, test_size=0.2, random_state=None)
aanrmod.fit(aanr, y)
plt.scatter(aanr, y, color='gray')
plt.plot(aanr, aanrmod.predict(aanr), color='red')

# %%
aanb = df['Avg. Area Number of Bedrooms']
aanb = aanb.to_numpy()
aanb = aanb.reshape(-1, 1)
aanbmod = LinearRegression(n_jobs=-1)
aanb_train, aanb_test, y_train, y_test = train_test_split(aanb, y, test_size=0.2, random_state=None)
aanbmod.fit(aanb, y)
plt.scatter(aanb, y, color='yellow')
plt.plot(aanb, aanbmod.predict(aanb), color='red')

# %%
ap = df['Area Population']
ap = ap.to_numpy()
ap = ap.reshape(-1, 1)
apmod = LinearRegression(n_jobs=-1)
ap_train, ap_test, y_train, y_test = train_test_split(ap, y, test_size=0.2, random_state=None)
apmod.fit(ap, y)
plt.scatter(ap, y, color='blue')
plt.plot(ap, apmod.predict(ap), color='red')
